# %% [markdown]
# # Importing important libraries for EDA

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Reading dataset

# %%
data = pd.read_csv('loan_approval_dataset.csv')

# %%
data
# Out:
#       loan_id   no_of_dependents      education  self_employed   income_annum  \
# 0           1                  2       Graduate             No        9600000
# 1           2                  0   Not Graduate            Yes        4100000
# 2           3                  3       Graduate             No        9100000
# 3           4                  3       Graduate             No        8200000
# 4           5                  5   Not Graduate            Yes        9800000
# ...       ...                ...            ...            ...            ...
# 4264     4265                  5       Graduate            Yes        1000000
# 4265     4266                  0   Not Graduate            Yes        3300000
# 4266     4267                  2   Not Graduate             No        6500000
# 4267     4268                  1   Not Graduate             No        4100000
# 4268     4269                  1       Graduate             No        9200000
#
# ...

# %%
df = data.copy()

# %% [markdown]
# # Display of all columns names

# %%
df.columns
# Out:
# Index(['loan_id', ' no_of_dependents', ' education', ' self_employed',
#        ' income_annum', ' loan_amount', ' loan_term', ' cibil_score',
#        ' residential_assets_value', ' commercial_assets_value',
#        ' luxury_assets_value', ' bank_asset_value', ' loan_status'],
#       dtype='object')

# %% [markdown]
# <h3>Striping space from the column names</h3>

# %%
new_header = list(df.columns.str.strip())

# %%
data.columns=new_header
df.columns=new_header

# %% [markdown]
# # Data Definition
# - Loan	A unique id
# - Gender	Gender of the applicant Male/female
# - Married	Marital Status of the applicant, values will be Yes/ No
# - Dependents	It tells whether the applicant has any dependents or not.
# - Education	It will tell us whether the applicant is Graduated or not.
# - Self_Employed	This defines that the applicant is self-employed i.e. Yes/ No
# - ApplicantIncome	Applicant income
# - CoapplicantIncome	Co-applicant income
# - LoanAmount	Loan amount (in thousands)
# - Loan_Amount_Term	Terms of loan (in months)
# - Credit_History	Credit history of individual’s repayment of their debts
# - Property_Area	Area of property i.e. Rural/Urban/Semi-urban
# - Loan_Status	Status of Loan Approved or not i.e. Y- Yes, N-No

# %% [markdown]
# # display datatype of columns

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4269 entries, 0 to 4268
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   loan_id                   4269 non-null   int64
#  1   no_of_dependents          4269 non-null   int64
#  2   education                 4269 non-null   object
#  3   self_employed             4269 non-null   object
#  4   income_annum              4269 non-null   int64
#  5   loan_amount               4269 non-null   int64
#  6   loan_term                 4269 non-null   int64
#  7   cibil_score               4269 non-null   int64
#  8   residential_assets_value  4269 non-null   int64
#  9   commercial_assets_value   4269 non-null   int64
#  10  luxury_assets_value       4269 non-null   int64
#  11  bank_asset_value          4269 non-null   int64
#  12  loan_status               4269 non-null   object
# dtypes: int64(10), object(3)
# memory usage: 433.7+ KB

# %%
data.dtypes
# Out:
# loan_id                      int64
# no_of_dependents             int64
# education                   object
# self_employed               object
# income_annum                 int64
# loan_amount                  int64
# loan_term                    int64
# cibil_score                  int64
# residential_assets_value     int64
# commercial_assets_value      int64
# luxury_assets_value          int64
# bank_asset_value             int64
# loan_status                 object
# dtype: object

# %% [markdown]
# # Statistical information

# %% [markdown]
# <h3>Numerical column</h3>

# %%
data.describe()
# Out:
#            loan_id  no_of_dependents  income_annum   loan_amount    loan_term  \
# count  4269.000000       4269.000000  4.269000e+03  4.269000e+03  4269.000000
# mean   2135.000000          2.498712  5.059124e+06  1.513345e+07    10.900445
# std    1232.498479          1.695910  2.806840e+06  9.043363e+06     5.709187
# min       1.000000          0.000000  2.000000e+05  3.000000e+05     2.000000
# 25%    1068.000000          1.000000  2.700000e+06  7.700000e+06     6.000000
# 50%    2135.000000          3.000000  5.100000e+06  1.450000e+07    10.000000
# 75%    3202.000000          4.000000  7.500000e+06  2.150000e+07    16.000000
# max    4269.000000          5.000000  9.900000e+06  3.950000e+07    20.000000
#
#        cibil_score  residential_assets_value  commercial_assets_value  \
# count  4269.000000              4.269000e+03             4.269000e+03
# mean    599.936051              7.472617e+06             4.973155e+06
# ...

# %% [markdown]
# <h3>Categorical columns</h3>

# %%
data.describe(exclude='number')
# Out:
#         education self_employed loan_status
# count        4269          4269        4269
# unique          2             2           2
# top      Graduate           Yes    Approved
# freq         2144          2150        2656

# %% [markdown]
# # Checking the missing data

# %%
data.isnull().sum()
# Out:
# loan_id                     0
# no_of_dependents            0
# education                   0
# self_employed               0
# income_annum                0
# loan_amount                 0
# loan_term                   0
# cibil_score                 0
# residential_assets_value    0
# commercial_assets_value     0
# luxury_assets_value         0
# bank_asset_value            0
# loan_status                 0
# dtype: int64

# %% [markdown]
# # checking duplicate entries

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [loan_id, no_of_dependents, education, self_employed, income_annum, loan_amount, loan_term, cibil_score, residential_assets_value, commercial_assets_value, luxury_assets_value, bank_asset_value, loan_status]
# Index: []

# %% [markdown]
# # Numerical and categorical columns segregation

# %%
num_col=data.select_dtypes(include='number').columns.to_list()
cat_col=data.select_dtypes(exclude='number').columns.to_list()

# %%
num_col
# Out:
# ['loan_id',
#  'no_of_dependents',
#  'income_annum',
#  'loan_amount',
#  'loan_term',
#  'cibil_score',
#  'residential_assets_value',
#  'commercial_assets_value',
#  'luxury_assets_value',
#  'bank_asset_value']

# %%
cat_col
# Out:
# ['education', 'self_employed', 'loan_status']

# %% [markdown]
# # checking for outliers

# %% [markdown]
# <h4 style="color: red;">histogram and kde ploting of all numerical features</h4>

# %%
for col in num_col:
    fig, axs = plt.subplots(1, 2, figsize=(10, 6))  

    sns.histplot(df[col], kde=True, ax=axs[0])  

    sns.kdeplot(df[col], ax=axs[1])
    
    print(f'Skewness of {col}: {df[col].skew()}')
# Out:
# Skewness of loan_id: 0.0
# Skewness of no_of_dependents: -0.01797054296784964
# Skewness of income_annum: -0.012814425096650109
# Skewness of loan_amount: 0.30872388482299223
# Skewness of loan_term: 0.036358907356478495
# Skewness of cibil_score: -0.009039277330065707
# Skewness of residential_assets_value: 0.9784505965115631
# Skewness of commercial_assets_value: 0.9577908874986114
# Skewness of luxury_assets_value: 0.3222075028955774
# Skewness of bank_asset_value: 0.5607250089736816

# %%
for col in num_col:
    plt.figure(figsize=(18,4))
    sns.boxplot(df,x=col)

# %%
df.columns
# Out:
# Index(['loan_id', 'no_of_dependents', 'education', 'self_employed',
#        'income_annum', 'loan_amount', 'loan_term', 'cibil_score',
#        'residential_assets_value', 'commercial_assets_value',
#        'luxury_assets_value', 'bank_asset_value', 'loan_status'],
#       dtype='object')

# %% [markdown]
# <h4 style="color: red;">boxplot of all numerical features</h4>

# %%
plt.figure(figsize=(8,4))
sns.boxplot(df,x='residential_assets_value')

plt.figure(figsize=(8,4))
sns.boxplot(df,x='commercial_assets_value')

plt.figure(figsize=(8,4))
sns.boxplot(df,x='bank_asset_value')
plt.show()

# %%
cols=['residential_assets_value', 'commercial_assets_value','bank_asset_value']

# %%
df[cols].describe()
# Out:
#        residential_assets_value  commercial_assets_value  bank_asset_value
# count              4.269000e+03             4.269000e+03      4.269000e+03
# mean               7.472617e+06             4.973155e+06      4.976692e+06
# std                6.503637e+06             4.388966e+06      3.250185e+06
# min               -1.000000e+05             0.000000e+00      0.000000e+00
# 25%                2.200000e+06             1.300000e+06      2.300000e+06
# 50%                5.600000e+06             3.700000e+06      4.600000e+06
# 75%                1.130000e+07             7.600000e+06      7.100000e+06
# max                2.910000e+07             1.940000e+07      1.470000e+07

# %%
df[cols]
# Out:
#       residential_assets_value  commercial_assets_value  bank_asset_value
# 0                      2400000                 17600000           8000000
# 1                      2700000                  2200000           3300000
# 2                      7100000                  4500000          12800000
# 3                     18200000                  3300000           7900000
# 4                     12400000                  8200000           5000000
# ...                        ...                      ...               ...
# 4264                   2800000                   500000            800000
# 4265                   4200000                  2900000           1900000
# 4266                   1200000                 12400000           7300000
# 4267                   8200000                   700000           5800000
# 4268                  17800000                 11800000          12000000
#
# [4269 rows x 3 columns]

# %%
for col in cols:
    df[col] = df[col]/10000

# %%
df[cols].describe()
# Out:
#        residential_assets_value  commercial_assets_value  bank_asset_value
# count               4269.000000              4269.000000       4269.000000
# mean                 747.261654               497.315531        497.669243
# std                  650.363659               438.896609        325.018531
# min                  -10.000000                 0.000000          0.000000
# 25%                  220.000000               130.000000        230.000000
# 50%                  560.000000               370.000000        460.000000
# 75%                 1130.000000               760.000000        710.000000
# max                 2910.000000              1940.000000       1470.000000

# %%
plt.figure(figsize=(18,6))
sns.kdeplot(df['residential_assets_value'])

plt.figure(figsize=(18,6))
sns.kdeplot(df['commercial_assets_value'])

plt.figure(figsize=(18,6))
sns.kdeplot(df['bank_asset_value'])
plt.show()

# %% [markdown]
# # Handling Outliers

# %% [markdown]
# # Handle Outliers:
# - Removal: You can choose to remove the data points that are identified as outliers.
#
# - Transformation: You can apply transformations to the data to reduce the impact of outliers (e.g., log transformation).
#
# - Capping: You can cap the extreme values at a certain threshold.
#
# - Imputation: You can replace outliers with more representative values (e.g., mean, median) if appropriate.

# %% [markdown]
# # Outlier Detection using Boundary Values
# - Boundary Values
# (mean (+or-) 3*std_dev)

# %%
df.columns
# Out:
# Index(['loan_id', 'no_of_dependents', 'education', 'self_employed',
#        'income_annum', 'loan_amount', 'loan_term', 'cibil_score',
#        'residential_assets_value', 'commercial_assets_value',
#        'luxury_assets_value', 'bank_asset_value', 'loan_status'],
#       dtype='object')

# %%
cols=['residential_assets_value', 'commercial_assets_value','bank_asset_value']

# %%
for col in cols:
    print(f'Upper Boundary Value for {col} : {round(df[col].mean()+3*df[col].std(),0)}')
    print(f'Lower Boundary Value for {col} : {df[col].mean()-3*df[col].std()}')
    print("*"*80)
# Out:
# Upper Boundary Value for residential_assets_value : 2698.0
# Lower Boundary Value for residential_assets_value : -1203.829322516142
# ********************************************************************************
# Upper Boundary Value for commercial_assets_value : 1814.0
# Lower Boundary Value for commercial_assets_value : -819.3742963223152
# ********************************************************************************
# Upper Boundary Value for bank_asset_value : 1473.0
# Lower Boundary Value for bank_asset_value : -477.38634832618567
# ********************************************************************************

# %%
# Upper/Lower Boundary Value for residential_assets_value 
rav_upper = df['residential_assets_value'].mean()+3*df['residential_assets_value'].std()
rav_lower = df['residential_assets_value'].mean()-3*df['residential_assets_value'].std()

# %%
df_rav=df[(df['residential_assets_value']>rav_upper) | (df['residential_assets_value']<rav_lower)]

# %%
len(df_rav)
# Out:
# 16

# %%
df_rav.index
# Out:
# Index([ 714,  892,  905,  987, 1468, 1591, 1965, 1997, 2318, 2586, 2927, 3119,
#        3234, 3782, 4042, 4074],
#       dtype='int64')

# %%
trim_df=df.drop(df_rav.index,axis=0)
trim_df.shape
# Out:
# (4253, 13)

# %%
# Upper/Lower Boundary Value for commercial_assets_value 
cav_upper = df['commercial_assets_value'].mean()+3*df['commercial_assets_value'].std()
cav_lower = df['commercial_assets_value'].mean()-3*df['commercial_assets_value'].std()

# %%
df_cav=df[(df['commercial_assets_value']>cav_upper) | (df['commercial_assets_value']<cav_lower)]

# %%
df_cav
# Out:
#       loan_id  no_of_dependents      education self_employed  income_annum  \
# 157       158                 5   Not Graduate           Yes       9900000
# 258       259                 0       Graduate            No       9800000
# 367       368                 1   Not Graduate           Yes       9400000
# 554       555                 3   Not Graduate           Yes       9500000
# 895       896                 0       Graduate            No       9400000
# 1029     1030                 2   Not Graduate           Yes       9500000
# 1254     1255                 5   Not Graduate           Yes       9800000
# 1272     1273                 5   Not Graduate            No       9900000
# 1304     1305                 2       Graduate           Yes       9400000
# 1761     1762                 2   Not Graduate           Yes       9800000
# 1768     1769                 4   Not Graduate            No       9900000
# ...

# %%
trim_df=trim_df.drop(df_cav.index,axis=0)

# %%
df['bank_asset_value'].plot(kind='box')
# Out:
# <Axes: >

# %%
(df['bank_asset_value']>df['bank_asset_value'].mean()+df['bank_asset_value'].std()*3).sum()
# Out:
# 0

# %%
df['bank_asset_value'].min()
# Out:
# 0.0

# %%
df['bank_asset_value'].mean()-df['bank_asset_value'].std()*3
# Out:
# -477.38634832618567

# %%
# Upper/Lower Boundary Value for bank_asset_value 
bav_upper = df['bank_asset_value'].mean()+3*df['bank_asset_value'].std()
bav_lower = df['bank_asset_value'].mean()-3*df['bank_asset_value'].std()

# %%
df_bav=df[(df['bank_asset_value']>bav_upper) | (df['bank_asset_value']<bav_lower)]

# %%
df_bav
# Out:
# Empty DataFrame
# Columns: [loan_id, no_of_dependents, education, self_employed, income_annum, loan_amount, loan_term, cibil_score, residential_assets_value, commercial_assets_value, luxury_assets_value, bank_asset_value, loan_status]
# Index: []

# %% [markdown]
# # Trimming

# %%
trimmed_df = df[(df['residential_assets_value']<rav_upper) & (df['residential_assets_value']>rav_lower)]

# %%
df.shape
# Out:
# (4269, 13)

# %%
trimmed_df.shape
# Out:
# (4253, 13)

# %%
sns.boxplot(trimmed_df['residential_assets_value'])
# Out:
# <Axes: >

# %%
plt.figure(figsize=(18,6))
sns.kdeplot(trim_df['residential_assets_value'])
# Out:
# <Axes: xlabel='residential_assets_value', ylabel='Density'>

# %%
trimmed_df = trimmed_df[(trimmed_df['commercial_assets_value']<cav_upper) & (trimmed_df['commercial_assets_value']>cav_lower)]

# %%
trimmed_df.shape
# Out:
# (4236, 13)

# %%
sns.boxplot(trim_df,x='commercial_assets_value')
# Out:
# <Axes: xlabel='commercial_assets_value'>

# %%
trimmed_df = trimmed_df[(trimmed_df['bank_asset_value']<bav_upper) & (trimmed_df['bank_asset_value']>bav_lower)]

# %% [markdown]
# # Capping

# %%
df['residential_assets_value']  = np.where(df['residential_assets_value']>rav_upper,rav_upper,
                                           np.where(df['residential_assets_value']<rav_lower,rav_lower,
                                                    df['residential_assets_value']))

# %%
sns.boxplot(df,x='residential_assets_value')
plt.show()

# %%
plt.figure(figsize=(18,6))
sns.kdeplot(df['residential_assets_value'])
# Out:
# <Axes: xlabel='residential_assets_value', ylabel='Density'>

# %%
df['commercial_assets_value']  = np.where(df['commercial_assets_value']>rav_upper,rav_upper,
                                           np.where(df['commercial_assets_value']<rav_lower,rav_lower,
                                                    df['commercial_assets_value']))

# %%
sns.boxplot(df,x='commercial_assets_value')
plt.show()

# %%
plt.figure(figsize=(18,6))
sns.kdeplot(df['commercial_assets_value'])
# Out:
# <Axes: xlabel='commercial_assets_value', ylabel='Density'>

# %%
lst = np.array([1,2,3,4,5,6,7,100,102,2000,2040,9460])

# %%
u= lst.mean()+3*lst.std()
l= lst.mean()-3*lst.std()

# %%
u
# Out:
# 8984.654645740418

# %%
sns.boxplot(lst)
# Out:
# <Axes: >

# %%
l = np.array([1,2,3,4,5,6,7])

# %%
sns.boxplot(l)
# Out:
# <Axes: >

# %% [markdown]
# # Outlier Detection using Z-score
#
# ### This technique is only used when the data is <u>Normally Distributed</u>
#
# ##### But for the sake of learning the technique, we will use this technique on the above columns.
#
# ![image.png](attachment:image.png)
#
#
# #### We will only consider values with z-score between -3 and 3 (there maybe situations where this range might change on the context of the data)
#
# <i>The range of valid Z-scores (-3 to 3) is a general guideline commonly used in the context of the Z-score method for identifying outliers. However, this range is not a strict rule and can be adjusted based on the specific characteristics and context of the data.<br><br>
# The choice of the range (-3 to 3) is somewhat arbitrary and stems from the empirical rule (also known as the 68-95-99.7 rule) for normally distributed data, where:</i>
#
# __About 68% of data falls within 1 standard deviation from the mean.<br><br>
# About 95% of data falls within 2 standard deviations from the mean.<br><br>
# About 99.7% of data falls within 3 standard deviations from the mean.<br><br>
# This rule is often used as a guideline to identify outliers. However, in practice, data may not always follow a perfect normal distribution, and the concept of what constitutes an "outlier" can vary based on the domain and context of the data analysis.__
#
# <i>In some cases, you might want to use a more lenient or more strict range of Z-scores based on your specific knowledge of the data and the problem you're trying to solve. For example, if you're working with medical data where extreme values are particularly relevant, you might choose a larger Z-score threshold to capture potential anomalies.
#
# Ultimately, the choice of the Z-score threshold depends on your understanding of the data and the goals of your analysis. It's a good practice to visualize the data, assess its distribution, and consider the domain knowledge before determining a suitable range for identifying outliers.</i>

# %%
df['z_score_rav'] =abs((df['residential_assets_value']-df['residential_assets_value'].mean())/df['residential_assets_value'].std())

# %%
df['z_score_rav']
# Out:
# 0       0.780766
# 1       0.734557
# 2       0.056832
# 3       1.652884
# 4       0.759519
#           ...
# 4264    0.719154
# 4265    0.503515
# 4266    0.965600
# 4267    0.112599
# 4268    1.591273
# Name: z_score_rav, Length: 4269, dtype: float64

# %%
df['z_score_rav'].describe()
# Out:
# count    4269.000000
# mean        0.817637
# std         0.575599
# min         0.004779
# 25%         0.395695
# 50%         0.759519
# 75%         1.058017
# max         3.005797
# Name: z_score_rav, dtype: float64

# %%
df[df['z_score_rav']>2.5]
# Out:
#       loan_id  no_of_dependents      education self_employed  income_annum  \
# 60         61                 2   Not Graduate            No       8500000
# 62         63                 5   Not Graduate           Yes       8800000
# 82         83                 2   Not Graduate           Yes       9900000
# 89         90                 2   Not Graduate            No       9800000
# 98         99                 4       Graduate            No       9400000
# ...       ...               ...            ...           ...           ...
# 4074     4075                 4   Not Graduate           Yes       9400000
# 4080     4081                 0   Not Graduate           Yes       8300000
# 4084     4085                 0   Not Graduate           Yes       9300000
# 4167     4168                 0       Graduate            No       9700000
# 4237     4238                 0   Not Graduate            No       9100000
#
# ...

# %% [markdown]
# # Trimming

# %%
trimmed_df = df[(df['z_score_rav']<2.5)]

print(trimmed_df.shape)
# Out:
# (4170, 14)

# %%
sns.kdeplot(trimmed_df['z_score_rav'])
# Out:
# <Axes: xlabel='z_score_rav', ylabel='Density'>

# %%
sns.boxplot(trimmed_df['residential_assets_value'])
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10,8))
plt.subplot(2,2,1)
sns.kdeplot(df['residential_assets_value'])

plt.subplot(2,2,2)
sns.boxplot(df['residential_assets_value'])

plt.subplot(2,2,3)
sns.kdeplot(trimmed_df['residential_assets_value'])

plt.subplot(2,2,4)
sns.boxplot(trimmed_df['residential_assets_value'])

plt.show()

# %%
trimmed_df[trimmed_df['z_score_rav']==trimmed_df['z_score_rav'].max()]['residential_assets_value']
# Out:
# 3456    2350.0
# 4258    2350.0
# Name: residential_assets_value, dtype: float64

# %%
trimmed_df[trimmed_df['z_score_rav']==trimmed_df['z_score_rav'].min()]['residential_assets_value']
# Out:
# 703     750.0
# 1314    750.0
# 1402    750.0
# 1864    750.0
# 1975    750.0
# 2156    750.0
# 2345    750.0
# 2577    750.0
# 2588    750.0
# 3183    750.0
# 3574    750.0
# 3657    750.0
# Name: residential_assets_value, dtype: float64

# %% [markdown]
# # Capping

# %%
cap_df = df.copy()

# %%
cap_df['residential_assets_value']=np.where(cap_df['z_score_rav']>2.5,cap_df['z_score_rav'].max(),cap_df['residential_assets_value'])

# %%
cap_df
# Out:
#       loan_id  no_of_dependents      education self_employed  income_annum  \
# 0           1                 2       Graduate            No       9600000
# 1           2                 0   Not Graduate           Yes       4100000
# 2           3                 3       Graduate            No       9100000
# 3           4                 3       Graduate            No       8200000
# 4           5                 5   Not Graduate           Yes       9800000
# ...       ...               ...            ...           ...           ...
# 4264     4265                 5       Graduate           Yes       1000000
# 4265     4266                 0   Not Graduate           Yes       3300000
# 4266     4267                 2   Not Graduate            No       6500000
# 4267     4268                 1   Not Graduate            No       4100000
# 4268     4269                 1       Graduate            No       9200000
#
# ...

# %%
plt.figure(figsize=(10,8))
plt.subplot(2,2,1)
sns.kdeplot(df['residential_assets_value'])

plt.subplot(2,2,2)
sns.boxplot(df['residential_assets_value'])

plt.subplot(2,2,3)
sns.kdeplot(cap_df['residential_assets_value'])

plt.subplot(2,2,4)
sns.boxplot(cap_df['residential_assets_value'])

plt.show()

# %% [markdown]
# # IQR method
#
# The Interquartile Range (IQR) method is another technique for identifying and handling outliers in a dataset. It's based on the distribution of data within the interquartile range, which is a measure of the spread of the middle 50% of the data. The IQR method is particularly useful for datasets that might not follow a normal distribution and where the concept of outliers might be different from that of normally distributed data.
#
# Here's how the IQR method works:
#
# Calculate Quartiles:
#
# * The first quartile (Q1) is the value below which 25% of the data falls.
# * The third quartile (Q3) is the value below which 75% of the data falls.
#
# Calculate Interquartile Range (IQR):
#
# * The interquartile range (IQR) is the difference between the third quartile (Q3) and the first quartile (Q1): IQR = Q3 - Q1.
#
# Identify Outliers:
#
# * Outliers are often defined as values that are below (Q1 - 1.5 * IQR) or above (Q3 + 1.5 * IQR).

# %%
def IQR_cal(col):
    q1=df[col].quantile(0.25)
    q3=df[col].quantile(0.75)
    
    iqr = q3-q1
    u_fence=q3+1.5*iqr
    l_fence=q1-1.5*iqr
    return u_fence,l_fence

# %%
upper_limit,lower_limit=IQR_cal('residential_assets_value')

# %%
upper_limit
# Out:
# 2495.0

# %%
lower_limit
# Out:
# -1145.0

# %% [markdown]
# # Trimming

# %%
trim_df= df[(df['residential_assets_value']<=upper_limit)&(df['residential_assets_value']>=lower_limit)]

# %%
trim_df.shape
# Out:
# (4217, 14)

# %%
plt.figure(figsize=(10,8))
plt.subplot(2,2,1)
sns.kdeplot(df['residential_assets_value'])

plt.subplot(2,2,2)
sns.boxplot(df['residential_assets_value'])

plt.subplot(2,2,3)
sns.kdeplot(trim_df['residential_assets_value'])

plt.subplot(2,2,4)
sns.boxplot(trim_df['residential_assets_value'])

plt.show()
