# %% [markdown]
# # Importing important libraries for EDA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import random

# %% [markdown]
# # Reading dataset

# %%
df = pd.read_csv('insurance1.csv')

# %% [markdown]
# # Data Definition
# - age : Age of the policyholder (Numeric)
# - sex: Gender of policyholder (Categoric)
# - weight: Weight of the policyholder (Numeric)
# - bmi: Body mass index, providing an understanding of body, weights that are relatively high or low relative to height, objective index of body weight (kg / m ^ 2) using the ratio of height to weight (Numeric)
# - no_of_dependents: Number of dependent persons on the policyholder (Numeric)
# - smoker: Indicates policyholder is a smoker or a non-smoker (non-smoker=0;smoker=1) (Categoric)
# - claim: The amount claimed by the policyholder (Numeric)
#
# - bloodpressure: Bloodpressure reading of policyholder (Numeric)
# - diabetes: Indicates policyholder suffers from diabetes or not (non-diabetic=0; diabetic=1) (Categoric)
# - regular_ex: A policyholder regularly excercises or not (no-excercise=0; excercise=1) (Categoric)
# - job_title: Job profile of the policyholder (Categoric)
# - city: The city in which the policyholder resides (Categoric)
# - hereditary_diseases: A policyholder suffering from a hereditary diseases or not (Categoric)

# %% [markdown]
# # top 5 rows of dataframe

# %%
df.head()
# Out:
#     age     sex  weight   bmi hereditary_diseases  no_of_dependents  smoker  \
# 0  60.0    male      64  24.3           NoDisease                 1       0
# 1  49.0  female      75  22.6           NoDisease                 1       0
# 2  32.0  female      64  17.8            Epilepsy                 2       1
# 3  61.0  female      53  36.4           NoDisease                 1       1
# 4  19.0  female      50  20.6           NoDisease                 0       0
#
#           city  bloodpressure  diabetes  regular_ex    job_title    claim
# 0      NewYork             72         0           0        Actor  13112.6
# 1       Boston             78         1           1     Engineer   9567.0
# 2  Phildelphia             88         1           1  Academician  32734.2
# 3    Pittsburg             72         1           0         Chef  48517.6
# 4      Buffalo             82         1           0   HomeMakers   1731.7

# %% [markdown]
# # Bottom 5 rows of dataframe

# %%
df.tail()
# Out:
#         age   sex  weight   bmi hereditary_diseases  no_of_dependents  smoker  \
# 14995  39.0  male      49  28.3           NoDisease                 1       1
# 14996  39.0  male      74  29.6           NoDisease                 4       0
# 14997  20.0  male      62  33.3           NoDisease                 0       0
# 14998  52.0  male      88  36.7           NoDisease                 0       0
# 14999  52.0  male      57  26.4           NoDisease                 3       0
#
#              city  bloodpressure  diabetes  regular_ex        job_title  \
# 14995    Florence             54         1           0        FilmMaker
# 14996       Miami             64         1           0          Student
# 14997       Tampa             52         1           0  FashionDesigner
# 14998  PanamaCity             70         1           0           Farmer
# 14999   Kingsport             72         1           0          Manager
#
#          claim
# 14995  21082.2
# 14996   7512.3
# ...

# %% [markdown]
# # Shape of dataframe

# %%
df.shape
# Out:
# (15000, 13)

# %%
print(f"No of rows: {df.shape[0]}\nNo of columns: {df.shape[1]}")
# Out:
# No of rows: 15000
# No of columns: 13

# %% [markdown]
# # checking duplicate entries

# %%
df[df.duplicated()]
# Out:
#         age     sex  weight   bmi hereditary_diseases  no_of_dependents  \
# 605    46.0  female      68   NaN           NoDisease                 2
# 608    27.0  female      82   NaN           NoDisease                 3
# 898    48.0  female      67  33.1           Alzheimer                 0
# 919    26.0    male      56  23.7           NoDisease                 2
# 970    48.0  female      70  28.9           NoDisease                 1
# ...     ...     ...     ...   ...                 ...               ...
# 14966  46.0    male      46  22.3           NoDisease                 0
# 14971  18.0  female      53  27.3           NoDisease                 3
# 14987  47.0    male      94  47.5           NoDisease                 1
# 14989  44.0    male      90  38.1           NoDisease                 1
# 14997  20.0    male      62  33.3           NoDisease                 0
#
#        smoker        city  bloodpressure  diabetes  regular_ex  \
# ...

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# # Checking for Null

# %%
tot = df.shape[0]

# %%
round((df.isnull().sum()/tot)*100,0)
# Out:
# age                    3.0
# sex                    0.0
# weight                 0.0
# bmi                    6.0
# hereditary_diseases    0.0
# no_of_dependents       0.0
# smoker                 0.0
# city                   0.0
# bloodpressure          0.0
# diabetes               0.0
# regular_ex             0.0
# job_title              0.0
# claim                  0.0
# dtype: float64

# %% [markdown]
# # Checking datatype of each feature

# %%
df.dtypes
# Out:
# age                    float64
# sex                     object
# weight                   int64
# bmi                    float64
# hereditary_diseases     object
# no_of_dependents         int64
# smoker                   int64
# city                    object
# bloodpressure            int64
# diabetes                 int64
# regular_ex               int64
# job_title               object
# claim                  float64
# dtype: object

# %% [markdown]
# # Converting Numerical column into categorical column

# %%
df['smoker'].replace({0:'no',1:'yes'},inplace=True)

# %%
df['regular_ex'].replace({0:'no',1:'yes'},inplace=True)

# %%
df['diabetes'].replace({0:'no',1:'yes'},inplace=True)

# %%
df.dtypes
# Out:
# age                    float64
# sex                     object
# weight                   int64
# bmi                    float64
# hereditary_diseases     object
# no_of_dependents         int64
# smoker                  object
# city                    object
# bloodpressure            int64
# diabetes                object
# regular_ex              object
# job_title               object
# claim                  float64
# dtype: object

# %% [markdown]
# # Statistical description of numerical features

# %%
df.describe()
# Out:
#                 age        weight           bmi  no_of_dependents  \
# count  13543.000000  13904.000000  13003.000000      13904.000000
# mean      39.556598     64.894347     30.273483          1.126438
# std       14.011047     13.675070      6.125247          1.225661
# min       18.000000     34.000000     16.000000          0.000000
# 25%       27.000000     54.000000     25.700000          0.000000
# 50%       40.000000     63.000000     29.400000          1.000000
# 75%       52.000000     76.000000     34.400000          2.000000
# max       64.000000     95.000000     53.100000          5.000000
#
#        bloodpressure         claim
# count   13904.000000  13904.000000
# mean       68.657652  13431.813744
# std        19.430514  12142.099413
# min         0.000000   1121.900000
# 25%        64.000000   4883.900000
# 50%        71.000000   9567.000000
# 75%        80.000000  16657.700000
# max       122.000000  63770.400000

# %% [markdown]
# # Statistical description of Categorical features

# %%
df.describe(exclude='number')
# Out:
#            sex hereditary_diseases smoker       city diabetes regular_ex  \
# count    13904               13904  13904      13904    13904      13904
# unique       2                  10      2         91        2          2
# top     female           NoDisease     no  Nashville      yes         no
# freq      7091               12965  11114        270    10722      10696
#
#        job_title
# count      13904
# unique        35
# top      Student
# freq        1220

# %% [markdown]
# # Display of all columns names

# %%
df.columns
# Out:
# Index(['age', 'sex', 'weight', 'bmi', 'hereditary_diseases',
#        'no_of_dependents', 'smoker', 'city', 'bloodpressure', 'diabetes',
#        'regular_ex', 'job_title', 'claim'],
#       dtype='object')

# %% [markdown]
# # Numerical and categorical columns segregation

# %%
num_col=df.select_dtypes(include='number').columns.to_list()
cat_col=df.select_dtypes(exclude='number').columns.to_list()

# %%
cat_col=[]
for col in df.columns:
    if df[col].dtypes=='O':
        cat_col.append(col)

# %% [raw]
# num_col=[]
# for col in df.columns:
#     if df[col].dtypes!='O':
#         num_col.append(col)

# %%
num_col
# Out:
# ['age', 'weight', 'bmi', 'no_of_dependents', 'bloodpressure', 'claim']

# %%
cat_col
# Out:
# ['sex',
#  'hereditary_diseases',
#  'smoker',
#  'city',
#  'diabetes',
#  'regular_ex',
#  'job_title']

# %%
#sns.set_style("dark")
sns.set_style("darkgrid", {"grid.color": ".9", "grid.linestyle": "-"})

# %% [markdown]
# # Univariate Analysis
# - Categorical Data

# %%
cat_col=df.select_dtypes(exclude='number').columns.to_list()

# %%
for col in cat_col:
    print(df[col].value_counts(),"\n\n")
# Out:
# sex
# female    7091
# male      6813
# Name: count, dtype: int64
#
#
# hereditary_diseases
# NoDisease       12965
# Alzheimer         137
# Diabetes          136
# Obesity           130
# EyeDisease        112
# Cancer            107
# Arthritis          88
# HeartDisease       87
# Epilepsy           77
# High BP            65
# Name: count, dtype: int64
#
#
# smoker
# no     11114
# yes     2790
# Name: count, dtype: int64
#
#
# city
# Nashville     270
# Memphis       269
# NewOrleans    268
# Charleston    267
# Brimingham    266
#              ...
# York           68
# Warwick        67
# Syracuse       67
# Baltimore      67
# Trenton        66
# Name: count, Length: 91, dtype: int64
#
#
# diabetes
# yes    10722
# no      3182
# Name: count, dtype: int64
#
#
# regular_ex
# no     10696
# yes     3208
# Name: count, dtype: int64
#
#
# job_title
# Student              1220
# HomeMakers            899
# Singer                697
# FilmMaker             675
# ...

# %% [markdown]
# # Countplot of all categorical columns

# %%
for col in cat_col:
    plt.figure(figsize=(5,5))
    ax=sns.countplot(x=col,data=df)
    for x in ax.containers:
        ax.bar_label(x)
        
    plt.show()

# %%
for col in cat_col:
    df[col].value_counts().plot(kind='pie',autopct='%.2f')      
    plt.show()

# %%
numerical=df.select_dtypes(include='number').columns.to_list()

# %%
df[numerical]
# Out:
#         age  weight   bmi  no_of_dependents  bloodpressure    claim
# 0      60.0      64  24.3                 1             72  13112.6
# 1      49.0      75  22.6                 1             78   9567.0
# 2      32.0      64  17.8                 2             88  32734.2
# 3      61.0      53  36.4                 1             72  48517.6
# 4      19.0      50  20.6                 0             82   1731.7
# ...     ...     ...   ...               ...            ...      ...
# 14994  38.0      71  27.3                 1              0   6555.1
# 14995  39.0      49  28.3                 1             54  21082.2
# 14996  39.0      74  29.6                 4             64   7512.3
# 14998  52.0      88  36.7                 0             70   9144.6
# 14999  52.0      57  26.4                 3             72  25992.8
#
# [13904 rows x 6 columns]

# %%
for col in numerical:
    fig,axs=plt.subplots(1,2, figsize=(10,6))
    sns.histplot(data=df,x=col,hue='sex', kde=True, ax=axs[0])
    sns.kdeplot(df[col], ax=axs[1])
    print(f"Skewness of {col}: {df[col].skew()}")
# Out:
# Skewness of age: 0.006109185887158953
# Skewness of weight: 0.28672897616305765
# Skewness of bmi: 0.3774683179762625
# Skewness of no_of_dependents: 0.9315683898573424
# Skewness of bloodpressure: -1.969797960048252
# Skewness of claim: 1.489221351406612

# %% [raw]
# Observation:

# %% [markdown]
# # Box plot for outlier detection

# %%
for col in numerical:
    plt.figure(figsize=(8,4))
    sns.boxplot(df,x=col)

# %% [raw]
# Observation:

# %% [markdown]
# # Bivariate/Multivariate Analysis

# %% [markdown]
# ![Feature_engg.png](attachment:Feature_engg.png)

# %%
sns.scatterplot(df,x='age',y='bmi',hue='sex',size='no_of_dependents')
plt.show()

# %%
sns.boxplot(x='sex',y='age',data=df)

# %%
sns.scatterplot(df,x='smoker',y='bmi')

# %%
sns.boxplot(x='smoker',y='bmi',data=df)

# %%
ax=sns.barplot(df, x='smoker',y='age',hue='sex')

for x in ax.containers:
    print(ax.bar_label(x))

# %%
df= pd.read_csv("insurance.csv")

# %%
df

# %%
plt.figure(figsize=(6,6))
ax=sns.countplot(data=df ,x='region',hue='sex')

for x in ax.containers:
        ax.bar_label(x)
plt.show()

# %% [markdown]
# ![Feature_engg.png](attachment:Feature_engg.png)

# %% [markdown]
# # Missing data handling

# %%
df = pd.read_csv('insurance1.csv')

# %%
df.shape
# Out:
# (15000, 13)

# %%
df.isnull().sum()
# Out:
# age                    396
# sex                      0
# weight                   0
# bmi                    956
# hereditary_diseases      0
# no_of_dependents         0
# smoker                   0
# city                     0
# bloodpressure            0
# diabetes                 0
# regular_ex               0
# job_title                0
# claim                    0
# dtype: int64

# %%
df.dtypes
# Out:
# age                    float64
# sex                     object
# weight                   int64
# bmi                    float64
# hereditary_diseases     object
# no_of_dependents         int64
# smoker                   int64
# city                    object
# bloodpressure            int64
# diabetes                 int64
# regular_ex               int64
# job_title               object
# claim                  float64
# dtype: object

# %%
i_age=list(df[df['age'].isnull()==True].index)

# %%
df.loc[i_age]
# Out:
#        age     sex  weight   bmi hereditary_diseases  no_of_dependents  \
# 76     NaN  female      88  29.6           NoDisease                 1
# 82     NaN  female      64  24.6           NoDisease                 2
# 105    NaN  female      73  20.2           NoDisease                 2
# 106    NaN  female      71  21.8           NoDisease                 1
# 110    NaN  female      70  34.3           NoDisease                 5
# ...    ...     ...     ...   ...                 ...               ...
# 14769  NaN  female      55  24.2           NoDisease                 5
# 14882  NaN  female      62  25.6           NoDisease                 4
# 14943  NaN    male      68  27.9           NoDisease                 0
# 14962  NaN    male      47  29.0           NoDisease                 1
# 14969  NaN    male      47  29.0           NoDisease                 1
#
#        smoker        city  bloodpressure  diabetes  regular_ex      job_title  \
# ...

# %% [markdown]
# # method1: dropna()
# - no of null rows have very less percentage of total

# %%
df.dropna()

# %% [markdown]
# # method2: inputing null values with Mean

# %% [markdown]
# # fillna()

# %%
df['age'].fillna(value=df['age'].mean(),inplace=True)

# %%
df['age'].mean()

# %%
df.isnull().sum()

# %%
df.loc[i_age]

# %% [markdown]
# # SimpleImputer()

# %%
from sklearn.impute import SimpleImputer

# %%
num_col=df.select_dtypes(include='number').columns.to_list()

# %%
imp=SimpleImputer(strategy='mean')

# %%
df_mean=imp.fit_transform(df[num_col])

# %%
df_mean
# Out:
# array([[6.00000e+01, 6.40000e+01, 2.43000e+01, ..., 0.00000e+00,
#         0.00000e+00, 1.31126e+04],
#        [4.90000e+01, 7.50000e+01, 2.26000e+01, ..., 1.00000e+00,
#         1.00000e+00, 9.56700e+03],
#        [3.20000e+01, 6.40000e+01, 1.78000e+01, ..., 1.00000e+00,
#         1.00000e+00, 3.27342e+04],
#        ...,
#        [2.00000e+01, 6.20000e+01, 3.33000e+01, ..., 1.00000e+00,
#         0.00000e+00, 1.39150e+03],
#        [5.20000e+01, 8.80000e+01, 3.67000e+01, ..., 1.00000e+00,
#         0.00000e+00, 9.14460e+03],
#        [5.20000e+01, 5.70000e+01, 2.64000e+01, ..., 1.00000e+00,
#         0.00000e+00, 2.59928e+04]])

# %%
imp.feature_names_in_
# Out:
# array(['age', 'weight', 'bmi', 'no_of_dependents', 'smoker',
#        'bloodpressure', 'diabetes', 'regular_ex', 'claim'], dtype=object)

# %%
df_mean=pd.DataFrame(df_mean,columns=imp.feature_names_in_)

# %%
df_mean
# Out:
#         age  weight   bmi  no_of_dependents  smoker  bloodpressure  diabetes  \
# 0      60.0    64.0  24.3               1.0     0.0           72.0       0.0
# 1      49.0    75.0  22.6               1.0     0.0           78.0       1.0
# 2      32.0    64.0  17.8               2.0     1.0           88.0       1.0
# 3      61.0    53.0  36.4               1.0     1.0           72.0       1.0
# 4      19.0    50.0  20.6               0.0     0.0           82.0       1.0
# ...     ...     ...   ...               ...     ...            ...       ...
# 14995  39.0    49.0  28.3               1.0     1.0           54.0       1.0
# 14996  39.0    74.0  29.6               4.0     0.0           64.0       1.0
# 14997  20.0    62.0  33.3               0.0     0.0           52.0       1.0
# 14998  52.0    88.0  36.7               0.0     0.0           70.0       1.0
# 14999  52.0    57.0  26.4               3.0     0.0           72.0       1.0
#
#        regular_ex    claim
# ...

# %%
imp_median=SimpleImputer(strategy='median')

# %%
df_median=imp_median.fit_transform(df[num_col])

# %%
df_median
# Out:
# array([[6.00000e+01, 6.40000e+01, 2.43000e+01, 1.00000e+00, 7.20000e+01,
#         1.31126e+04],
#        [4.90000e+01, 7.50000e+01, 2.26000e+01, 1.00000e+00, 7.80000e+01,
#         9.56700e+03],
#        [3.20000e+01, 6.40000e+01, 1.78000e+01, 2.00000e+00, 8.80000e+01,
#         3.27342e+04],
#        ...,
#        [2.00000e+01, 6.20000e+01, 3.33000e+01, 0.00000e+00, 5.20000e+01,
#         1.39150e+03],
#        [5.20000e+01, 8.80000e+01, 3.67000e+01, 0.00000e+00, 7.00000e+01,
#         9.14460e+03],
#        [5.20000e+01, 5.70000e+01, 2.64000e+01, 3.00000e+00, 7.20000e+01,
#         2.59928e+04]])

# %%
for num in num_col:
    fig, axs = plt.subplots(1, 2, figsize=(6, 3))  
    
    axs[0].set_title('Original')
    axs[1].set_title('Mean')
#     sns.histplot(X_median[num], kde=True, ax=axs[0])  


    sns.kdeplot(df[num], ax=axs[0])
    sns.kdeplot(df_mean[num], ax=axs[1])
#   sns.kdeplot(X_median[num], ax=axs[2])
    
    print(f'WithoutImputationn_Skewness of {num}: {df[num].skew()}')
    print(f'MeanImputation_Skewness of {num}: {df_mean[num].skew()}')
#    print(f'MedianImputation_Skewness of {num}: {X_median[num].skew()}')
    print('='*50)
# Out:
# WithoutImputationn_Skewness of age: 0.005576775986078496
# MeanImputation_Skewness of age: 0.006190055330509191
# ...
# WithoutImputationn_Skewness of weight: 0.28603415578268687
# MeanImputation_Skewness of weight: 0.28672897616305765
# ...
# WithoutImputationn_Skewness of bmi: 0.3752585894901583
# MeanImputation_Skewness of bmi: 0.390324091092988
# ...
# WithoutImputationn_Skewness of no_of_dependents: 0.9289345167145934
# MeanImputation_Skewness of no_of_dependents: 0.9315683898573424
# ...
# WithoutImputationn_Skewness of bloodpressure: -1.9638790071826926
# MeanImputation_Skewness of bloodpressure: -1.969797960048252
# ...
# WithoutImputationn_Skewness of claim: 1.4978293015042263
# MeanImputation_Skewness of claim: 1.489221351406612
# ...

# %%
df_median=pd.DataFrame(df_median,columns=imp_median.feature_names_in_)

# %%
df_median
# Out:
#         age  weight   bmi  no_of_dependents  bloodpressure    claim
# 0      60.0    64.0  24.3               1.0           72.0  13112.6
# 1      49.0    75.0  22.6               1.0           78.0   9567.0
# 2      32.0    64.0  17.8               2.0           88.0  32734.2
# 3      61.0    53.0  36.4               1.0           72.0  48517.6
# 4      19.0    50.0  20.6               0.0           82.0   1731.7
# ...     ...     ...   ...               ...            ...      ...
# 14995  39.0    49.0  28.3               1.0           54.0  21082.2
# 14996  39.0    74.0  29.6               4.0           64.0   7512.3
# 14997  20.0    62.0  33.3               0.0           52.0   1391.5
# 14998  52.0    88.0  36.7               0.0           70.0   9144.6
# 14999  52.0    57.0  26.4               3.0           72.0  25992.8
#
# [15000 rows x 6 columns]

# %%
for num in num_col:
    fig, axs = plt.subplots(1, 3, figsize=(6, 3))  
    
    axs[0].set_title('Original')
    axs[1].set_title('Mean')
    axs[2].set_title('Median')
#     sns.histplot(X_median[num], kde=True, ax=axs[0])  


    sns.kdeplot(df[num], ax=axs[0])
    sns.kdeplot(df_mean[num], ax=axs[1])
    sns.kdeplot(df_median[num], ax=axs[2])
    
    print(f'WithoutImputationn_Skewness of {num}: {df[num].skew()}')
    print(f'MeanImputation_Skewness of {num}: {df_mean[num].skew()}')
    print(f'MedianImputation_Skewness of {num}: {df_median[num].skew()}')
    print('='*50)
# Out:
# WithoutImputationn_Skewness of age: 0.005576775986078496
# MeanImputation_Skewness of age: 0.006190055330509191
# MedianImputation_Skewness of age: 0.003060988584646111
# ...
# WithoutImputationn_Skewness of weight: 0.28603415578268687
# MeanImputation_Skewness of weight: 0.28672897616305765
# MedianImputation_Skewness of weight: 0.28603415578268687
# ...
# WithoutImputationn_Skewness of bmi: 0.3752585894901583
# MeanImputation_Skewness of bmi: 0.390324091092988
# MedianImputation_Skewness of bmi: 0.4148254755182088
# ...
# WithoutImputationn_Skewness of no_of_dependents: 0.9289345167145934
# MeanImputation_Skewness of no_of_dependents: 0.9315683898573424
# MedianImputation_Skewness of no_of_dependents: 0.9289345167145934
# ...
# WithoutImputationn_Skewness of bloodpressure: -1.9638790071826926
# MeanImputation_Skewness of bloodpressure: -1.969797960048252
# MedianImputation_Skewness of bloodpressure: -1.9638790071826926
# ...
# WithoutImputationn_Skewness of claim: 1.4978293015042263
# ...

# %%
df
# Out:
#         age     sex  weight   bmi hereditary_diseases  no_of_dependents  \
# 0      60.0    male      64  24.3           NoDisease                 1
# 1      49.0  female      75  22.6           NoDisease                 1
# 2      32.0  female      64  17.8            Epilepsy                 2
# 3      61.0  female      53  36.4           NoDisease                 1
# 4      19.0  female      50  20.6           NoDisease                 0
# ...     ...     ...     ...   ...                 ...               ...
# 14994  38.0  female      71  27.3           NoDisease                 1
# 14995  39.0    male      49  28.3           NoDisease                 1
# 14996  39.0    male      74  29.6           NoDisease                 4
# 14998  52.0    male      88  36.7           NoDisease                 0
# 14999  52.0    male      57  26.4           NoDisease                 3
#
#        smoker         city  bloodpressure  diabetes  regular_ex    job_title  \
# ...

# %%
df_mean
# Out:
#         age  weight   bmi  no_of_dependents  smoker  bloodpressure  diabetes  \
# 0      60.0    64.0  24.3               1.0     0.0           72.0       0.0
# 1      49.0    75.0  22.6               1.0     0.0           78.0       1.0
# 2      32.0    64.0  17.8               2.0     1.0           88.0       1.0
# 3      61.0    53.0  36.4               1.0     1.0           72.0       1.0
# 4      19.0    50.0  20.6               0.0     0.0           82.0       1.0
# ...     ...     ...   ...               ...     ...            ...       ...
# 14971  39.0    49.0  28.3               1.0     1.0           54.0       1.0
# 14972  39.0    74.0  29.6               4.0     0.0           64.0       1.0
# 14973  20.0    62.0  33.3               0.0     0.0           52.0       1.0
# 14974  52.0    88.0  36.7               0.0     0.0           70.0       1.0
# 14975  52.0    57.0  26.4               3.0     0.0           72.0       1.0
#
#        regular_ex    claim  imputed_age
# ...

# %%
df_median
# Out:
#         age  weight   bmi  no_of_dependents  bloodpressure    claim
# 0      60.0    64.0  24.3               1.0           72.0  13112.6
# 1      49.0    75.0  22.6               1.0           78.0   9567.0
# 2      32.0    64.0  17.8               2.0           88.0  32734.2
# 3      61.0    53.0  36.4               1.0           72.0  48517.6
# 4      19.0    50.0  20.6               0.0           82.0   1731.7
# ...     ...     ...   ...               ...            ...      ...
# 14995  39.0    49.0  28.3               1.0           54.0  21082.2
# 14996  39.0    74.0  29.6               4.0           64.0   7512.3
# 14997  20.0    62.0  33.3               0.0           52.0   1391.5
# 14998  52.0    88.0  36.7               0.0           70.0   9144.6
# 14999  52.0    57.0  26.4               3.0           72.0  25992.8
#
# [15000 rows x 6 columns]

# %%
df['imputed_age']=df_mean['age']

# %%
df['imputed_bmi']=df_mean['bmi']

# %%
df_mean.isnull().sum()
# Out:
# age                 0
# weight              0
# bmi                 0
# no_of_dependents    0
# smoker              0
# bloodpressure       0
# diabetes            0
# regular_ex          0
# claim               0
# dtype: int64

# %%
df_mean
# Out:
#         age  weight   bmi  no_of_dependents  bloodpressure    claim
# 0      60.0    64.0  24.3               1.0           72.0  13112.6
# 1      49.0    75.0  22.6               1.0           78.0   9567.0
# 2      32.0    64.0  17.8               2.0           88.0  32734.2
# 3      61.0    53.0  36.4               1.0           72.0  48517.6
# 4      19.0    50.0  20.6               0.0           82.0   1731.7
# ...     ...     ...   ...               ...            ...      ...
# 13899  38.0    71.0  27.3               1.0            0.0   6555.1
# 13900  39.0    49.0  28.3               1.0           54.0  21082.2
# 13901  39.0    74.0  29.6               4.0           64.0   7512.3
# 13902  52.0    88.0  36.7               0.0           70.0   9144.6
# 13903  52.0    57.0  26.4               3.0           72.0  25992.8
#
# [13904 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# age                    361
# sex                      0
# weight                   0
# bmi                    901
# hereditary_diseases      0
# no_of_dependents         0
# smoker                   0
# city                     0
# bloodpressure            0
# diabetes                 0
# regular_ex               0
# job_title                0
# claim                    0
# imputed_age              0
# imputed_bmi              0
# dtype: int64

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#         age     sex  weight   bmi hereditary_diseases  no_of_dependents  \
# 0      60.0    male      64  24.3           NoDisease                 1
# 1      49.0  female      75  22.6           NoDisease                 1
# 2      32.0  female      64  17.8            Epilepsy                 2
# 3      61.0  female      53  36.4           NoDisease                 1
# 4      19.0  female      50  20.6           NoDisease                 0
# ...     ...     ...     ...   ...                 ...               ...
# 14994  38.0  female      71  27.3           NoDisease                 1
# 14995  39.0    male      49  28.3           NoDisease                 1
# 14996  39.0    male      74  29.6           NoDisease                 4
# 14998  52.0    male      88  36.7           NoDisease                 0
# 14999  52.0    male      57  26.4           NoDisease                 3
#
#        smoker         city  bloodpressure  diabetes  regular_ex    job_title  \
# ...

# %%
sns.kdeplot(df['bmi'],color='b')
sns.kdeplot(df['imputed_bmi'],color='g')
# Out:
# <Axes: xlabel='bmi', ylabel='Density'>

# %% [markdown]
# # Categorical Data
# - Most Frequent Value imputation (mode)
# - Missing Category

# %%
df.dtypes
# Out:
# age                    float64
# sex                     object
# weight                   int64
# bmi                    float64
# hereditary_diseases     object
# no_of_dependents         int64
# smoker                  object
# city                    object
# bloodpressure            int64
# diabetes                object
# regular_ex              object
# job_title               object
# claim                  float64
# imputed_age            float64
# imputed_bmi            float64
# dtype: object

# %%
cat_col=df.select_dtypes(exclude='number').columns.to_list()

# %%
cat_col
# Out:
# ['sex',
#  'hereditary_diseases',
#  'smoker',
#  'city',
#  'diabetes',
#  'regular_ex',
#  'job_title']

# %%
for cat in cat_col:
    null_val = df[cat].isnull().sum()

    null_percent = round(df[cat].isnull().mean()*100,3)
    
    print(f'Null Values for {cat}: {null_val} ')
    print(f'Null % for {cat}:      {null_percent} % ')
    print('='*25)
# Out:
# Null Values for sex: 0
# Null % for sex:      0.0 %
# ...
# Null Values for hereditary_diseases: 0
# Null % for hereditary_diseases:      0.0 %
# ...
# Null Values for smoker: 0
# Null % for smoker:      0.0 %
# ...
# Null Values for city: 0
# Null % for city:      0.0 %
# ...
# Null Values for diabetes: 0
# Null % for diabetes:      0.0 %
# ...
# Null Values for regular_ex: 0
# Null % for regular_ex:      0.0 %
# ...
# Null Values for job_title: 0
# Null % for job_title:      0.0 %
# ...
